# %% [markdown]
# <a href="https://colab.research.google.com/github/jayashankarreddyy/Neural-Networks-and-Deep-Learning/blob/main/autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam

# Load data
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Flatten
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# Architecture
input_layer = Input(shape=(784,))
encoded = Dense(128, activation="relu")(input_layer)
latent = Dense(64, activation="relu")(encoded)

decoded = Dense(128, activation="relu")(latent)
output = Dense(784, activation="sigmoid")(decoded)

autoencoder = Model(input_layer, output)

autoencoder.compile(
    optimizer=Adam(),
    loss="mse"
)

autoencoder.fit(
    x_train, x_train,
    epochs=10,
    batch_size=256,
    validation_data=(x_test, x_test)
)

autoencoder.summary()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0874 - val_loss: 0.0305
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0270 - val_loss: 0.0190
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0182 - val_loss: 0.0149
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0147 - val_loss: 0.0127
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0127 - val_loss: 0.0112
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0112 - val_loss: 0.0101
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0102 - val_loss: 0.0094
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0095 - val_loss: 0.0088
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0089 - val_loss: 0.0083
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0083 - val_loss: 0.0077
# Model: "functional"
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# Load Data
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

# Model
class Autoencoder(Model):
    def __init__(self):
        super().__init__()
        self.encoder = tf.keras.Sequential([
            layers.Flatten(),
            layers.Dense(64, activation='relu')
        ])
        self.decoder = tf.keras.Sequential([
            layers.Dense(784, activation='sigmoid'),
            layers.Reshape((28,28))
        ])

    def call(self, x):
        return self.decoder(self.encoder(x))

autoencoder = Autoencoder()
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

autoencoder.fit(x_train, x_train,
                epochs=10,
                batch_size=256,
                validation_data=(x_test, x_test))

# Test
encoded = autoencoder.encoder(x_test)
decoded = autoencoder.decoder(encoded)

n = 10
plt.figure(figsize=(20,4))
for i in range(n):
    plt.subplot(2,n,i+1)
    plt.imshow(x_test[i])
    plt.axis("off")

    plt.subplot(2,n,i+1+n)
    plt.imshow(decoded[i])
    plt.axis("off")
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0815 - val_loss: 0.0284
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0258 - val_loss: 0.0203
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0190 - val_loss: 0.0163
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0155 - val_loss: 0.0142
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0138 - val_loss: 0.0129
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0126 - val_loss: 0.0121
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0119 - val_loss: 0.0116
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0113 - val_loss: 0.0111
# Epoch 9/10
# ...
